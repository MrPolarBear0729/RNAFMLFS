# %%
#导入包与设定随机函数

import os
import pandas as pd
import fm
import torch
from torch import nn
from torch.utils.data import DataLoader,Dataset,random_split,TensorDataset
import numpy as np
import random
import torch.nn.functional as F

def seed_torch(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

seed_torch(42)

# %%
#导入RNA-FM
def get_device():
    return 'cuda' if torch.cuda.is_available() else 'cpu'
device = get_device()
print(f"使用的设备是: {device}")
backbone, alphabet = fm.pretrained.rna_fm_t12()
print("create RNA-FM_backbone sucessfully")
# Out:
# 使用的设备是: cuda
# create RNA-FM_backbone sucessfully

# %%
#读取并提取数据信息
publictest=pd.read_csv('../inputdata/inputdata.csv')
publictestdata=[]
for i in range(0,len(publictest['sequence'])):
    publictestdata.append(('RNA'+str(i),publictest['sequence'][i]))
batch_converter = alphabet.get_batch_converter()
batch_labels_publictestdata, batch_strs_publictestdata, batch_tokens_publictestdata = batch_converter(publictestdata)

# %%
#定义模型结构
class Model(nn.Module):
    def __init__(self,Backbone=backbone):
        super().__init__()
        self.RNAFM=Backbone
        self.lstm1 = nn.LSTM(input_size=640, hidden_size=256,batch_first=True,bidirectional=True,num_layers=2)
        self.gru1 = nn.GRU(input_size=256*2,hidden_size=256,batch_first=True,bidirectional=True,num_layers=2)
        self.linear1 = nn.Linear(256*2, 3)
    def forward(self,inputx):
        result = self.RNAFM(inputx,repr_layers=[12])["representations"][12]
        lstm_out1, (h_n1, h_c1) = self.lstm1(result)
        gru1_out1,_ = self.gru1(lstm_out1)
        linear1_out=self.linear1(gru1_out1)
        return linear1_out

# %%
publictestdataset = TensorDataset(batch_tokens_publictestdata)
publictest_data_loader = DataLoader(publictestdataset,batch_size=20)

# %%
pred_model = torch.load('./model.pt').to(device)
pred_model.eval()
# Out:
# Model(
#   (RNAFM): RNABertModel(
#     (embed_tokens): Embedding(25, 640, padding_idx=1)
#     (layers): ModuleList(
#       (0): TransformerLayer(
#         (self_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=640, out_features=640, bias=True)
#           (v_proj): Linear(in_features=640, out_features=640, bias=True)
#           (q_proj): Linear(in_features=640, out_features=640, bias=True)
#           (out_proj): Linear(in_features=640, out_features=640, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=640, out_features=5120, bias=True)
#         (fc2): Linear(in_features=5120, out_features=640, bias=True)
#         (final_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): TransformerLayer(
#         (self_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=640, out_features=640, bias=True)
#           (v_proj): Linear(in_features=640, out_features=640, bias=True)
#           (q_proj): Linear(in_features=640, out_features=640, bias=True)
#           (out_proj): Linear(in_features=640, out_features=640, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=640, out_features=5120, bias=True)
#         (fc2): Linear(in_features=5120, out_features=640, bias=True)
#         (final_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       )
#       (2): TransformerLayer(
#         (self_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=640, out_features=640, bias=True)
#           (v_proj): Linear(in_features=640, out_features=640, bias=True)
#           (q_proj): Linear(in_features=640, out_features=640, bias=True)
#           (out_proj): Linear(in_features=640, out_features=640, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=640, out_features=5120, bias=True)
#         (fc2): Linear(in_features=5120, out_features=640, bias=True)
#         (final_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): TransformerLayer(
#         (self_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=640, out_features=640, bias=True)
#           (v_proj): Linear(in_features=640, out_features=640, bias=True)
#           (q_proj): Linear(in_features=640, out_features=640, bias=True)
#           (out_proj): Linear(in_features=640, out_features=640, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=640, out_features=5120, bias=True)
#         (fc2): Linear(in_features=5120, out_features=640, bias=True)
#         (final_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       )
#       (4): TransformerLayer(
#         (self_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=640, out_features=640, bias=True)
#           (v_proj): Linear(in_features=640, out_features=640, bias=True)
#           (q_proj): Linear(in_features=640, out_features=640, bias=True)
#           (out_proj): Linear(in_features=640, out_features=640, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=640, out_features=5120, bias=True)
#         (fc2): Linear(in_features=5120, out_features=640, bias=True)
#         (final_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): TransformerLayer(
#         (self_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=640, out_features=640, bias=True)
#           (v_proj): Linear(in_features=640, out_features=640, bias=True)
#           (q_proj): Linear(in_features=640, out_features=640, bias=True)
#           (out_proj): Linear(in_features=640, out_features=640, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=640, out_features=5120, bias=True)
#         (fc2): Linear(in_features=5120, out_features=640, bias=True)
#         (final_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       )
#       (6): TransformerLayer(
#         (self_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=640, out_features=640, bias=True)
#           (v_proj): Linear(in_features=640, out_features=640, bias=True)
#           (q_proj): Linear(in_features=640, out_features=640, bias=True)
#           (out_proj): Linear(in_features=640, out_features=640, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=640, out_features=5120, bias=True)
#         (fc2): Linear(in_features=5120, out_features=640, bias=True)
#         (final_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       )
#       (7): TransformerLayer(
#         (self_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=640, out_features=640, bias=True)
#           (v_proj): Linear(in_features=640, out_features=640, bias=True)
#           (q_proj): Linear(in_features=640, out_features=640, bias=True)
#           (out_proj): Linear(in_features=640, out_features=640, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=640, out_features=5120, bias=True)
#         (fc2): Linear(in_features=5120, out_features=640, bias=True)
#         (final_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       )
#       (8): TransformerLayer(
#         (self_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=640, out_features=640, bias=True)
#           (v_proj): Linear(in_features=640, out_features=640, bias=True)
#           (q_proj): Linear(in_features=640, out_features=640, bias=True)
#           (out_proj): Linear(in_features=640, out_features=640, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=640, out_features=5120, bias=True)
#         (fc2): Linear(in_features=5120, out_features=640, bias=True)
#         (final_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       )
#       (9): TransformerLayer(
#         (self_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=640, out_features=640, bias=True)
#           (v_proj): Linear(in_features=640, out_features=640, bias=True)
#           (q_proj): Linear(in_features=640, out_features=640, bias=True)
#           (out_proj): Linear(in_features=640, out_features=640, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=640, out_features=5120, bias=True)
#         (fc2): Linear(in_features=5120, out_features=640, bias=True)
#         (final_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       )
#       (10): TransformerLayer(
#         (self_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=640, out_features=640, bias=True)
#           (v_proj): Linear(in_features=640, out_features=640, bias=True)
#           (q_proj): Linear(in_features=640, out_features=640, bias=True)
#           (out_proj): Linear(in_features=640, out_features=640, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=640, out_features=5120, bias=True)
#         (fc2): Linear(in_features=5120, out_features=640, bias=True)
#         (final_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       )
#       (11): TransformerLayer(
#         (self_attn): MultiheadAttention(
#           (k_proj): Linear(in_features=640, out_features=640, bias=True)
#           (v_proj): Linear(in_features=640, out_features=640, bias=True)
#           (q_proj): Linear(in_features=640, out_features=640, bias=True)
#           (out_proj): Linear(in_features=640, out_features=640, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=640, out_features=5120, bias=True)
#         (fc2): Linear(in_features=5120, out_features=640, bias=True)
#         (final_layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (contact_head): ContactPredictionHead(
#       (regression): Linear(in_features=240, out_features=1, bias=True)
#       (activation): Sigmoid()
#     )
#     (embed_positions): LearnedPositionalEmbedding(1026, 640, padding_idx=1)
#     (emb_layer_norm_before): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#     (emb_layer_norm_after): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#     (lm_head): RobertaLMHead(
#       (dense): Linear(in_features=640, out_features=640, bias=True)
#       (layer_norm): LayerNorm((640,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lstm1): LSTM(640, 256, num_layers=2, batch_first=True, bidirectional=True)
#   (gru1): GRU(512, 256, num_layers=2, batch_first=True, bidirectional=True)
#   (linear1): Linear(in_features=512, out_features=3, bias=True)
# )

# %%
i=0
pred_len = 107
for x in publictest_data_loader:
    Pred_x = x[0].to(device)
    Pred_y = pred_model(Pred_x)[:,:pred_len,:]
    for j in range(0,Pred_y.shape[0]):
        np.savetxt('../tempfile/'+str(i*20+(j+1))+'.csv',Pred_y[j].cpu().detach().numpy(),delimiter=',')
    i+=1

# %%
#合并CSV文件
folder_path = '../tempfile/'
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]
csv_files = sorted(csv_files, key=lambda x: int(x.split('.')[0]))

# %%
merged_data = pd.DataFrame()
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path,header=None)
    merged_data = pd.concat([merged_data, df], ignore_index=False,axis=0)
merged_data.reset_index(inplace=True,drop=True)

# %%
def delete_all_files_in_folder(folder_path):
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        try:
            if os.path.isfile(file_path):
                os.remove(file_path)
                
            elif os.path.isdir(file_path):
                delete_all_files_in_folder(file_path)
        except Exception as e:
            print(f"删除文件失败: {file_path}, 错误信息: {e}")

# 指定要删除文件的文件夹路径
folder_to_delete = "../tempfile"

# 调用函数删除文件夹中的所有文件
delete_all_files_in_folder(folder_to_delete)
# Out:
# 已删除文件: ../tempfile/309.csv
# 已删除文件: ../tempfile/58.csv
# 已删除文件: ../tempfile/343.csv
# 已删除文件: ../tempfile/483.csv
# 已删除文件: ../tempfile/523.csv
# 已删除文件: ../tempfile/400.csv
# 已删除文件: ../tempfile/160.csv
# 已删除文件: ../tempfile/454.csv
# 已删除文件: ../tempfile/145.csv
# 已删除文件: ../tempfile/206.csv
# 已删除文件: ../tempfile/433.csv
# 已删除文件: ../tempfile/69.csv
# 已删除文件: ../tempfile/30.csv
# 已删除文件: ../tempfile/74.csv
# 已删除文件: ../tempfile/462.csv
# 已删除文件: ../tempfile/406.csv
# 已删除文件: ../tempfile/582.csv
# 已删除文件: ../tempfile/271.csv
# 已删除文件: ../tempfile/326.csv
# 已删除文件: ../tempfile/315.csv
# 已删除文件: ../tempfile/378.csv
# 已删除文件: ../tempfile/112.csv
# 已删除文件: ../tempfile/261.csv
# 已删除文件: ../tempfile/449.csv
# 已删除文件: ../tempfile/127.csv
# 已删除文件: ../tempfile/299.csv
# 已删除文件: ../tempfile/109.csv
# 已删除文件: ../tempfile/231.csv
# 已删除文件: ../tempfile/295.csv
# 已删除文件: ../tempfile/603.csv
# 已删除文件: ../tempfile/527.csv
# 已删除文件: ../tempfile/338.csv
# 已删除文件: ../tempfile/275.csv
# 已删除文件: ../tempfile/625.csv
# 已删除文件: ../tempfile/210.csv
# 已删除文件: ../tempfile/176.csv
# 已删除文件: ../tempfile/233.csv
# 已删除文件: ../tempfile/316.csv
# 已删除文件: ../tempfile/365.csv
# 已删除文件: ../tempfile/96.csv
# 已删除文件: ../tempfile/558.csv
# 已删除文件: ../tempfile/511.csv
# 已删除文件: ../tempfile/156.csv
# 已删除文件: ../tempfile/65.csv
# 已删除文件: ../tempfile/478.csv
# 已删除文件: ../tempfile/115.csv
# 已删除文件: ../tempfile/561.csv
# 已删除文件: ../tempfile/384.csv
# 已删除文件: ../tempfile/55.csv
# 已删除文件: ../tempfile/391.csv
# 已删除文件: ../tempfile/222.csv
# 已删除文件: ../tempfile/43.csv
# 已删除文件: ../tempfile/52.csv
# 已删除文件: ../tempfile/278.csv
# 已删除文件: ../tempfile/113.csv
# 已删除文件: ../tempfile/609.csv
# 已删除文件: ../tempfile/50.csv
# 已删除文件: ../tempfile/576.csv
# 已删除文件: ../tempfile/423.csv
# 已删除文件: ../tempfile/276.csv
# 已删除文件: ../tempfile/232.csv
# 已删除文件: ../tempfile/235.csv
# 已删除文件: ../tempfile/240.csv
# 已删除文件: ../tempfile/274.csv
# 已删除文件: ../tempfile/14.csv
# 已删除文件: ../tempfile/348.csv
# 已删除文件: ../tempfile/9.csv
# 已删除文件: ../tempfile/183.csv
# 已删除文件: ../tempfile/438.csv
# 已删除文件: ../tempfile/72.csv
# 已删除文件: ../tempfile/622.csv
# 已删除文件: ../tempfile/514.csv
# 已删除文件: ../tempfile/570.csv
# 已删除文件: ../tempfile/84.csv
# 已删除文件: ../tempfile/201.csv
# 已删除文件: ../tempfile/185.csv
# 已删除文件: ../tempfile/87.csv
# 已删除文件: ../tempfile/368.csv
# 已删除文件: ../tempfile/362.csv
# 已删除文件: ../tempfile/61.csv
# 已删除文件: ../tempfile/236.csv
# 已删除文件: ../tempfile/90.csv
# 已删除文件: ../tempfile/526.csv
# 已删除文件: ../tempfile/165.csv
# 已删除文件: ../tempfile/474.csv
# 已删除文件: ../tempfile/184.csv
# 已删除文件: ../tempfile/250.csv
# 已删除文件: ../tempfile/83.csv
# 已删除文件: ../tempfile/106.csv
# 已删除文件: ../tempfile/73.csv
# 已删除文件: ../tempfile/245.csv
# 已删除文件: ../tempfile/610.csv
# 已删除文件: ../tempfile/482.csv
# 已删除文件: ../tempfile/599.csv
# 已删除文件: ../tempfile/596.csv
# 已删除文件: ../tempfile/414.csv
# 已删除文件: ../tempfile/403.csv
# 已删除文件: ../tempfile/216.csv
# 已删除文件: ../tempfile/13.csv
# 已删除文件: ../tempfile/441.csv
# 已删除文件: ../tempfile/177.csv
# 已删除文件: ../tempfile/252.csv
# 已删除文件: ../tempfile/555.csv
# 已删除文件: ../tempfile/339.csv
# 已删除文件: ../tempfile/164.csv
# 已删除文件: ../tempfile/509.csv
# 已删除文件: ../tempfile/258.csv
# 已删除文件: ../tempfile/243.csv
# 已删除文件: ../tempfile/605.csv
# 已删除文件: ../tempfile/209.csv
# 已删除文件: ../tempfile/244.csv
# 已删除文件: ../tempfile/571.csv
# 已删除文件: ../tempfile/148.csv
# 已删除文件: ../tempfile/284.csv
# 已删除文件: ../tempfile/62.csv
# 已删除文件: ../tempfile/404.csv
# 已删除文件: ../tempfile/323.csv
# 已删除文件: ../tempfile/297.csv
# 已删除文件: ../tempfile/461.csv
# 已删除文件: ../tempfile/617.csv
# 已删除文件: ../tempfile/310.csv
# 已删除文件: ../tempfile/330.csv
# 已删除文件: ../tempfile/42.csv
# 已删除文件: ../tempfile/388.csv
# 已删除文件: ../tempfile/480.csv
# 已删除文件: ../tempfile/390.csv
# 已删除文件: ../tempfile/376.csv
# 已删除文件: ../tempfile/29.csv
# 已删除文件: ../tempfile/581.csv
# 已删除文件: ../tempfile/534.csv
# 已删除文件: ../tempfile/353.csv
# 已删除文件: ../tempfile/546.csv
# 已删除文件: ../tempfile/473.csv
# 已删除文件: ../tempfile/16.csv
# 已删除文件: ../tempfile/572.csv
# 已删除文件: ../tempfile/446.csv
# 已删除文件: ../tempfile/409.csv
# 已删除文件: ../tempfile/92.csv
# 已删除文件: ../tempfile/269.csv
# 已删除文件: ../tempfile/63.csv
# 已删除文件: ../tempfile/196.csv
# 已删除文件: ../tempfile/125.csv
# 已删除文件: ../tempfile/607.csv
# 已删除文件: ../tempfile/47.csv
# 已删除文件: ../tempfile/505.csv
# 已删除文件: ../tempfile/230.csv
# 已删除文件: ../tempfile/44.csv
# 已删除文件: ../tempfile/179.csv
# 已删除文件: ../tempfile/56.csv
# 已删除文件: ../tempfile/102.csv
# 已删除文件: ../tempfile/496.csv
# 已删除文件: ../tempfile/191.csv
# 已删除文件: ../tempfile/288.csv
# 已删除文件: ../tempfile/355.csv
# 已删除文件: ../tempfile/277.csv
# 已删除文件: ../tempfile/181.csv
# 已删除文件: ../tempfile/501.csv
# 已删除文件: ../tempfile/340.csv
# 已删除文件: ../tempfile/207.csv
# 已删除文件: ../tempfile/159.csv
# 已删除文件: ../tempfile/99.csv
# 已删除文件: ../tempfile/46.csv
# 已删除文件: ../tempfile/455.csv
# 已删除文件: ../tempfile/239.csv
# 已删除文件: ../tempfile/97.csv
# 已删除文件: ../tempfile/398.csv
# 已删除文件: ../tempfile/467.csv
# 已删除文件: ../tempfile/273.csv
# 已删除文件: ../tempfile/450.csv
# 已删除文件: ../tempfile/537.csv
# 已删除文件: ../tempfile/122.csv
# 已删除文件: ../tempfile/289.csv
# 已删除文件: ../tempfile/120.csv
# 已删除文件: ../tempfile/351.csv
# 已删除文件: ../tempfile/130.csv
# 已删除文件: ../tempfile/611.csv
# 已删除文件: ../tempfile/465.csv
# 已删除文件: ../tempfile/214.csv
# 已删除文件: ../tempfile/614.csv
# 已删除文件: ../tempfile/456.csv
# 已删除文件: ../tempfile/180.csv
# 已删除文件: ../tempfile/593.csv
# 已删除文件: ../tempfile/447.csv
# 已删除文件: ../tempfile/588.csv
# 已删除文件: ../tempfile/419.csv
# 已删除文件: ../tempfile/272.csv
# 已删除文件: ../tempfile/116.csv
# 已删除文件: ../tempfile/431.csv
# 已删除文件: ../tempfile/407.csv
# 已删除文件: ../tempfile/516.csv
# 已删除文件: ../tempfile/484.csv
# 已删除文件: ../tempfile/38.csv
# 已删除文件: ../tempfile/389.csv
# 已删除文件: ../tempfile/36.csv
# 已删除文件: ../tempfile/397.csv
# 已删除文件: ../tempfile/521.csv
# 已删除文件: ../tempfile/281.csv
# 已删除文件: ../tempfile/373.csv
# 已删除文件: ../tempfile/536.csv
# 已删除文件: ../tempfile/5.csv
# 已删除文件: ../tempfile/566.csv
# 已删除文件: ../tempfile/347.csv
# 已删除文件: ../tempfile/294.csv
# 已删除文件: ../tempfile/542.csv
# 已删除文件: ../tempfile/321.csv
# 已删除文件: ../tempfile/408.csv
# 已删除文件: ../tempfile/499.csv
# 已删除文件: ../tempfile/327.csv
# 已删除文件: ../tempfile/549.csv
# 已删除文件: ../tempfile/331.csv
# 已删除文件: ../tempfile/137.csv
# 已删除文件: ../tempfile/75.csv
# 已删除文件: ../tempfile/557.csv
# 已删除文件: ../tempfile/1.csv
# 已删除文件: ../tempfile/628.csv
# 已删除文件: ../tempfile/519.csv
# 已删除文件: ../tempfile/405.csv
# 已删除文件: ../tempfile/317.csv
# 已删除文件: ../tempfile/215.csv
# 已删除文件: ../tempfile/6.csv
# 已删除文件: ../tempfile/435.csv
# 已删除文件: ../tempfile/228.csv
# 已删除文件: ../tempfile/308.csv
# 已删除文件: ../tempfile/40.csv
# 已删除文件: ../tempfile/440.csv
# 已删除文件: ../tempfile/459.csv
# 已删除文件: ../tempfile/158.csv
# 已删除文件: ../tempfile/100.csv
# 已删除文件: ../tempfile/153.csv
# 已删除文件: ../tempfile/346.csv
# 已删除文件: ../tempfile/132.csv
# 已删除文件: ../tempfile/163.csv
# 已删除文件: ../tempfile/285.csv
# 已删除文件: ../tempfile/199.csv
# 已删除文件: ../tempfile/280.csv
# 已删除文件: ../tempfile/98.csv
# 已删除文件: ../tempfile/626.csv
# 已删除文件: ../tempfile/300.csv
# 已删除文件: ../tempfile/51.csv
# 已删除文件: ../tempfile/227.csv
# 已删除文件: ../tempfile/15.csv
# 已删除文件: ../tempfile/357.csv
# 已删除文件: ../tempfile/528.csv
# 已删除文件: ../tempfile/413.csv
# 已删除文件: ../tempfile/541.csv
# 已删除文件: ../tempfile/101.csv
# 已删除文件: ../tempfile/178.csv
# 已删除文件: ../tempfile/322.csv
# 已删除文件: ../tempfile/587.csv
# 已删除文件: ../tempfile/424.csv
# 已删除文件: ../tempfile/522.csv
# 已删除文件: ../tempfile/108.csv
# 已删除文件: ../tempfile/270.csv
# 已删除文件: ../tempfile/562.csv
# 已删除文件: ../tempfile/59.csv
# 已删除文件: ../tempfile/513.csv
# 已删除文件: ../tempfile/213.csv
# 已删除文件: ../tempfile/226.csv
# 已删除文件: ../tempfile/129.csv
# 已删除文件: ../tempfile/306.csv
# 已删除文件: ../tempfile/111.csv
# 已删除文件: ../tempfile/2.csv
# 已删除文件: ../tempfile/251.csv
# 已删除文件: ../tempfile/126.csv
# 已删除文件: ../tempfile/350.csv
# 已删除文件: ../tempfile/144.csv
# 已删除文件: ../tempfile/319.csv
# 已删除文件: ../tempfile/469.csv
# 已删除文件: ../tempfile/547.csv
# 已删除文件: ../tempfile/17.csv
# 已删除文件: ../tempfile/385.csv
# 已删除文件: ../tempfile/249.csv
# 已删除文件: ../tempfile/579.csv
# 已删除文件: ../tempfile/81.csv
# 已删除文件: ../tempfile/428.csv
# 已删除文件: ../tempfile/314.csv
# 已删除文件: ../tempfile/172.csv
# 已删除文件: ../tempfile/190.csv
# 已删除文件: ../tempfile/421.csv
# 已删除文件: ../tempfile/147.csv
# 已删除文件: ../tempfile/254.csv
# 已删除文件: ../tempfile/567.csv
# 已删除文件: ../tempfile/217.csv
# 已删除文件: ../tempfile/356.csv
# 已删除文件: ../tempfile/293.csv
# 已删除文件: ../tempfile/104.csv
# 已删除文件: ../tempfile/225.csv
# 已删除文件: ../tempfile/363.csv
# 已删除文件: ../tempfile/37.csv
# 已删除文件: ../tempfile/524.csv
# 已删除文件: ../tempfile/291.csv
# 已删除文件: ../tempfile/492.csv
# 已删除文件: ../tempfile/488.csv
# 已删除文件: ../tempfile/512.csv
# 已删除文件: ../tempfile/345.csv
# 已删除文件: ../tempfile/208.csv
# 已删除文件: ../tempfile/525.csv
# 已删除文件: ../tempfile/494.csv
# 已删除文件: ../tempfile/195.csv
# 已删除文件: ../tempfile/411.csv
# 已删除文件: ../tempfile/324.csv
# 已删除文件: ../tempfile/372.csv
# 已删除文件: ../tempfile/219.csv
# 已删除文件: ../tempfile/152.csv
# 已删除文件: ../tempfile/545.csv
# 已删除文件: ../tempfile/255.csv
# 已删除文件: ../tempfile/518.csv
# 已删除文件: ../tempfile/487.csv
# 已删除文件: ../tempfile/128.csv
# 已删除文件: ../tempfile/552.csv
# 已删除文件: ../tempfile/543.csv
# 已删除文件: ../tempfile/392.csv
# 已删除文件: ../tempfile/560.csv
# 已删除文件: ../tempfile/166.csv
# 已删除文件: ../tempfile/565.csv
# 已删除文件: ../tempfile/192.csv
# 已删除文件: ../tempfile/175.csv
# 已删除文件: ../tempfile/303.csv
# 已删除文件: ../tempfile/627.csv
# 已删除文件: ../tempfile/358.csv
# 已删除文件: ../tempfile/531.csv
# 已删除文件: ../tempfile/286.csv
# 已删除文件: ../tempfile/3.csv
# 已删除文件: ../tempfile/577.csv
# 已删除文件: ../tempfile/168.csv
# 已删除文件: ../tempfile/265.csv
# 已删除文件: ../tempfile/600.csv
# 已删除文件: ../tempfile/436.csv
# 已删除文件: ../tempfile/66.csv
# 已删除文件: ../tempfile/352.csv
# 已删除文件: ../tempfile/203.csv
# 已删除文件: ../tempfile/553.csv
# 已删除文件: ../tempfile/460.csv
# 已删除文件: ../tempfile/377.csv
# 已删除文件: ../tempfile/601.csv
# 已删除文件: ../tempfile/395.csv
# 已删除文件: ../tempfile/591.csv
# 已删除文件: ../tempfile/470.csv
# 已删除文件: ../tempfile/590.csv
# 已删除文件: ../tempfile/364.csv
# 已删除文件: ../tempfile/457.csv
# 已删除文件: ../tempfile/221.csv
# 已删除文件: ../tempfile/383.csv
# 已删除文件: ../tempfile/430.csv
# 已删除文件: ../tempfile/548.csv
# 已删除文件: ../tempfile/485.csv
# 已删除文件: ../tempfile/535.csv
# 已删除文件: ../tempfile/8.csv
# 已删除文件: ../tempfile/475.csv
# 已删除文件: ../tempfile/241.csv
# 已删除文件: ../tempfile/453.csv
# 已删除文件: ../tempfile/489.csv
# 已删除文件: ../tempfile/91.csv
# 已删除文件: ../tempfile/22.csv
# 已删除文件: ../tempfile/374.csv
# 已删除文件: ../tempfile/530.csv
# 已删除文件: ../tempfile/563.csv
# 已删除文件: ../tempfile/312.csv
# 已删除文件: ../tempfile/507.csv
# 已删除文件: ../tempfile/117.csv
# 已删除文件: ../tempfile/296.csv
# 已删除文件: ../tempfile/141.csv
# 已删除文件: ../tempfile/77.csv
# 已删除文件: ../tempfile/11.csv
# 已删除文件: ../tempfile/267.csv
# 已删除文件: ../tempfile/344.csv
# 已删除文件: ../tempfile/80.csv
# 已删除文件: ../tempfile/67.csv
# 已删除文件: ../tempfile/287.csv
# 已删除文件: ../tempfile/204.csv
# 已删除文件: ../tempfile/349.csv
# 已删除文件: ../tempfile/290.csv
# 已删除文件: ../tempfile/301.csv
# 已删除文件: ../tempfile/4.csv
# 已删除文件: ../tempfile/624.csv
# 已删除文件: ../tempfile/170.csv
# 已删除文件: ../tempfile/283.csv
# 已删除文件: ../tempfile/394.csv
# 已删除文件: ../tempfile/266.csv
# 已删除文件: ../tempfile/502.csv
# 已删除文件: ../tempfile/491.csv
# 已删除文件: ../tempfile/157.csv
# 已删除文件: ../tempfile/568.csv
# 已删除文件: ../tempfile/212.csv
# 已删除文件: ../tempfile/7.csv
# 已删除文件: ../tempfile/515.csv
# 已删除文件: ../tempfile/263.csv
# 已删除文件: ../tempfile/256.csv
# 已删除文件: ../tempfile/248.csv
# 已删除文件: ../tempfile/420.csv
# 已删除文件: ../tempfile/416.csv
# 已删除文件: ../tempfile/437.csv
# 已删除文件: ../tempfile/82.csv
# 已删除文件: ../tempfile/412.csv
# 已删除文件: ../tempfile/143.csv
# 已删除文件: ../tempfile/118.csv
# 已删除文件: ../tempfile/94.csv
# 已删除文件: ../tempfile/434.csv
# 已删除文件: ../tempfile/597.csv
# 已删除文件: ../tempfile/242.csv
# 已删除文件: ../tempfile/529.csv
# 已删除文件: ../tempfile/471.csv
# 已删除文件: ../tempfile/53.csv
# 已删除文件: ../tempfile/259.csv
# 已删除文件: ../tempfile/86.csv
# 已删除文件: ../tempfile/370.csv
# 已删除文件: ../tempfile/188.csv
# 已删除文件: ../tempfile/425.csv
# 已删除文件: ../tempfile/329.csv
# 已删除文件: ../tempfile/468.csv
# 已删除文件: ../tempfile/618.csv
# 已删除文件: ../tempfile/328.csv
# 已删除文件: ../tempfile/140.csv
# 已删除文件: ../tempfile/402.csv
# 已删除文件: ../tempfile/25.csv
# 已删除文件: ../tempfile/211.csv
# 已删除文件: ../tempfile/361.csv
# 已删除文件: ../tempfile/615.csv
# 已删除文件: ../tempfile/544.csv
# 已删除文件: ../tempfile/71.csv
# 已删除文件: ../tempfile/578.csv
# 已删除文件: ../tempfile/616.csv
# 已删除文件: ../tempfile/517.csv
# 已删除文件: ../tempfile/85.csv
# 已删除文件: ../tempfile/135.csv
# 已删除文件: ../tempfile/169.csv
# 已删除文件: ../tempfile/110.csv
# 已删除文件: ../tempfile/472.csv
# 已删除文件: ../tempfile/335.csv
# 已删除文件: ../tempfile/341.csv
# 已删除文件: ../tempfile/21.csv
# 已删除文件: ../tempfile/371.csv
# 已删除文件: ../tempfile/229.csv
# 已删除文件: ../tempfile/490.csv
# 已删除文件: ../tempfile/382.csv
# 已删除文件: ../tempfile/18.csv
# 已删除文件: ../tempfile/253.csv
# 已删除文件: ../tempfile/613.csv
# 已删除文件: ../tempfile/608.csv
# 已删除文件: ../tempfile/35.csv
# 已删除文件: ../tempfile/452.csv
# 已删除文件: ../tempfile/320.csv
# 已删除文件: ../tempfile/592.csv
# 已删除文件: ../tempfile/354.csv
# 已删除文件: ../tempfile/26.csv
# 已删除文件: ../tempfile/105.csv
# 已删除文件: ../tempfile/34.csv
# 已删除文件: ../tempfile/481.csv
# 已删除文件: ../tempfile/551.csv
# 已删除文件: ../tempfile/336.csv
# 已删除文件: ../tempfile/386.csv
# 已删除文件: ../tempfile/442.csv
# 已删除文件: ../tempfile/279.csv
# 已删除文件: ../tempfile/619.csv
# 已删除文件: ../tempfile/418.csv
# 已删除文件: ../tempfile/167.csv
# 已删除文件: ../tempfile/189.csv
# 已删除文件: ../tempfile/486.csv
# 已删除文件: ../tempfile/262.csv
# 已删除文件: ../tempfile/426.csv
# 已删除文件: ../tempfile/583.csv
# 已删除文件: ../tempfile/586.csv
# 已删除文件: ../tempfile/197.csv
# 已删除文件: ../tempfile/173.csv
# 已删除文件: ../tempfile/194.csv
# 已删除文件: ../tempfile/136.csv
# 已删除文件: ../tempfile/477.csv
# 已删除文件: ../tempfile/45.csv
# 已删除文件: ../tempfile/48.csv
# 已删除文件: ../tempfile/495.csv
# 已删除文件: ../tempfile/193.csv
# 已删除文件: ../tempfile/500.csv
# 已删除文件: ../tempfile/60.csv
# 已删除文件: ../tempfile/445.csv
# 已删除文件: ../tempfile/119.csv
# 已删除文件: ../tempfile/57.csv
# 已删除文件: ../tempfile/154.csv
# 已删除文件: ../tempfile/401.csv
# 已删除文件: ../tempfile/313.csv
# 已删除文件: ../tempfile/174.csv
# 已删除文件: ../tempfile/33.csv
# 已删除文件: ../tempfile/64.csv
# 已删除文件: ../tempfile/103.csv
# 已删除文件: ../tempfile/387.csv
# 已删除文件: ../tempfile/202.csv
# 已删除文件: ../tempfile/292.csv
# 已删除文件: ../tempfile/49.csv
# 已删除文件: ../tempfile/307.csv
# 已删除文件: ../tempfile/451.csv
# 已删除文件: ../tempfile/131.csv
# 已删除文件: ../tempfile/31.csv
# 已删除文件: ../tempfile/95.csv
# 已删除文件: ../tempfile/27.csv
# 已删除文件: ../tempfile/359.csv
# 已删除文件: ../tempfile/595.csv
# 已删除文件: ../tempfile/139.csv
# 已删除文件: ../tempfile/304.csv
# 已删除文件: ../tempfile/264.csv
# 已删除文件: ../tempfile/24.csv
# 已删除文件: ../tempfile/448.csv
# 已删除文件: ../tempfile/538.csv
# 已删除文件: ../tempfile/238.csv
# 已删除文件: ../tempfile/41.csv
# 已删除文件: ../tempfile/532.csv
# 已删除文件: ../tempfile/134.csv
# 已删除文件: ../tempfile/539.csv
# 已删除文件: ../tempfile/325.csv
# 已删除文件: ../tempfile/114.csv
# 已删除文件: ../tempfile/107.csv
# 已删除文件: ../tempfile/70.csv
# 已删除文件: ../tempfile/318.csv
# 已删除文件: ../tempfile/12.csv
# 已删除文件: ../tempfile/23.csv
# 已删除文件: ../tempfile/381.csv
# 已删除文件: ../tempfile/623.csv
# 已删除文件: ../tempfile/342.csv
# 已删除文件: ../tempfile/171.csv
# 已删除文件: ../tempfile/150.csv
# 已删除文件: ../tempfile/476.csv
# 已删除文件: ../tempfile/574.csv
# 已删除文件: ../tempfile/182.csv
# 已删除文件: ../tempfile/520.csv
# 已删除文件: ../tempfile/439.csv
# 已删除文件: ../tempfile/186.csv
# 已删除文件: ../tempfile/28.csv
# 已删除文件: ../tempfile/366.csv
# 已删除文件: ../tempfile/573.csv
# 已删除文件: ../tempfile/369.csv
# 已删除文件: ../tempfile/155.csv
# 已删除文件: ../tempfile/332.csv
# 已删除文件: ../tempfile/510.csv
# 已删除文件: ../tempfile/133.csv
# 已删除文件: ../tempfile/415.csv
# 已删除文件: ../tempfile/224.csv
# 已删除文件: ../tempfile/151.csv
# 已删除文件: ../tempfile/68.csv
# 已删除文件: ../tempfile/302.csv
# 已删除文件: ../tempfile/564.csv
# 已删除文件: ../tempfile/123.csv
# 已删除文件: ../tempfile/162.csv
# 已删除文件: ../tempfile/146.csv
# 已删除文件: ../tempfile/79.csv
# 已删除文件: ../tempfile/604.csv
# 已删除文件: ../tempfile/443.csv
# 已删除文件: ../tempfile/380.csv
# 已删除文件: ../tempfile/417.csv
# 已删除文件: ../tempfile/629.csv
# 已删除文件: ../tempfile/121.csv
# 已删除文件: ../tempfile/78.csv
# 已删除文件: ../tempfile/559.csv
# 已删除文件: ../tempfile/463.csv
# 已删除文件: ../tempfile/584.csv
# 已删除文件: ../tempfile/504.csv
# 已删除文件: ../tempfile/20.csv
# 已删除文件: ../tempfile/360.csv
# 已删除文件: ../tempfile/540.csv
# 已删除文件: ../tempfile/598.csv
# 已删除文件: ../tempfile/497.csv
# 已删除文件: ../tempfile/479.csv
# 已删除文件: ../tempfile/200.csv
# 已删除文件: ../tempfile/260.csv
# 已删除文件: ../tempfile/333.csv
# 已删除文件: ../tempfile/533.csv
# 已删除文件: ../tempfile/498.csv
# 已删除文件: ../tempfile/422.csv
# 已删除文件: ../tempfile/427.csv
# 已删除文件: ../tempfile/149.csv
# 已删除文件: ../tempfile/432.csv
# 已删除文件: ../tempfile/550.csv
# 已删除文件: ../tempfile/464.csv
# 已删除文件: ../tempfile/234.csv
# 已删除文件: ../tempfile/621.csv
# 已删除文件: ../tempfile/220.csv
# 已删除文件: ../tempfile/19.csv
# 已删除文件: ../tempfile/585.csv
# 已删除文件: ../tempfile/556.csv
# 已删除文件: ../tempfile/375.csv
# 已删除文件: ../tempfile/393.csv
# 已删除文件: ../tempfile/76.csv
# 已删除文件: ../tempfile/138.csv
# 已删除文件: ../tempfile/367.csv
# 已删除文件: ../tempfile/268.csv
# 已删除文件: ../tempfile/198.csv
# 已删除文件: ../tempfile/606.csv
# 已删除文件: ../tempfile/282.csv
# 已删除文件: ../tempfile/88.csv
# 已删除文件: ../tempfile/334.csv
# 已删除文件: ../tempfile/589.csv
# 已删除文件: ../tempfile/594.csv
# 已删除文件: ../tempfile/444.csv
# 已删除文件: ../tempfile/298.csv
# 已删除文件: ../tempfile/466.csv
# 已删除文件: ../tempfile/396.csv
# 已删除文件: ../tempfile/410.csv
# 已删除文件: ../tempfile/508.csv
# 已删除文件: ../tempfile/54.csv
# 已删除文件: ../tempfile/569.csv
# 已删除文件: ../tempfile/124.csv
# 已删除文件: ../tempfile/10.csv
# 已删除文件: ../tempfile/493.csv
# 已删除文件: ../tempfile/161.csv
# 已删除文件: ../tempfile/89.csv
# 已删除文件: ../tempfile/218.csv
# 已删除文件: ../tempfile/602.csv
# 已删除文件: ../tempfile/247.csv
# 已删除文件: ../tempfile/506.csv
# 已删除文件: ../tempfile/503.csv
# 已删除文件: ../tempfile/246.csv
# 已删除文件: ../tempfile/337.csv
# 已删除文件: ../tempfile/620.csv
# 已删除文件: ../tempfile/554.csv
# 已删除文件: ../tempfile/458.csv
# 已删除文件: ../tempfile/39.csv
# 已删除文件: ../tempfile/223.csv
# 已删除文件: ../tempfile/575.csv
# 已删除文件: ../tempfile/305.csv
# 已删除文件: ../tempfile/612.csv
# 已删除文件: ../tempfile/399.csv
# 已删除文件: ../tempfile/187.csv
# 已删除文件: ../tempfile/93.csv
# 已删除文件: ../tempfile/205.csv
# 已删除文件: ../tempfile/311.csv
# 已删除文件: ../tempfile/429.csv
# 已删除文件: ../tempfile/379.csv
# 已删除文件: ../tempfile/237.csv
# 已删除文件: ../tempfile/257.csv
# 已删除文件: ../tempfile/32.csv
# 已删除文件: ../tempfile/142.csv
# 已删除文件: ../tempfile/580.csv

# %%
templist = []
for k in publictest['id'].to_list():
    for q in range(0,pred_len):
        templist.append(k+'_'+str(q))
merged_data['id_seqpos']=templist
merged_data.columns=["reactivity", "deg_Mg_pH10", "deg_Mg_50C",'id_seqpos']
merged_data.to_csv('../outputdata/result.csv',index=False)
